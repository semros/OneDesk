# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %% [markdown]
# # 1. Let's start with cleaning the data set named 'Business Interactions'

# %%
df_BI = pd.read_csv("/content/drive/MyDrive/Python Codes/data/raw/BusinessInteraction.csv", sep=';', on_bad_lines='warn')
df_BI.head()
# Out:
#    BusinessInteractionId   InstanceId        StepId         ActionCd  \
# 0            10230767264  10003850078  1.000012e+12         SaveStep
# 1            10230767256  10003850078           NaN  WorkflowStarted
# 2            10230767260  10003850078  1.000012e+12        EmailSent
# 3            10232343851  10003850078           NaN   CancelInstance
# 4            10230767273  10003850078  1.000012e+12         SaveStep
#
#    ActionUserId StatusCd EntityStatusCd  RelatedPartyId             Reason  \
# 0        573540        W            NEW          347878                NaN
# 1        573540        W            NEW          573540                NaN
# 2        573540        W            NEW          347878                NaN
# 3             4        W            NEW               4  AUTO DRAFT DELETE
# 4        573540        W            NEW          347878                NaN
#
#                  StartTime                  EndTime AppActionCd  CreateUserId  \
# 0  2021-03-19 23:26:18.479  2021-03-19 23:26:18.479         NaN        573540
# 1  2021-03-19 23:26:02.260  2021-03-19 23:26:02.260         NaN        573540
# 2  2021-03-19 23:26:14.104  2021-03-19 23:26:14.104         NaN        573540
# 3  2021-03-24 10:05:48.456  2021-03-24 10:05:48.456      HideBI             4
# 4  2021-03-19 23:26:21.202  2021-03-19 23:26:21.202         NaN        573540
#
#             CreateUserTime  UpdateUserId UpdateUserTime  TargetUserId  \
# 0  2021-03-19 23:26:18.588           NaN            NaN             0
# 1  2021-03-19 23:26:11.510           NaN            NaN             0
# 2  2021-03-19 23:26:14.729           NaN            NaN             0
# 3  2021-03-24 10:05:52.972           NaN            NaN             0
# 4  2021-03-19 23:26:21.390           NaN            NaN             0
#
#    TargetGroupId
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
#print(f"Number of rows and columns in df_BI: {df_BI.shape}")
print(f"Number of rows in df_BI: {df_BI.shape[0]}")
print(f"Number of columns in df_BI: {df_BI.shape[1]}")
# Out:
# Number of rows in df_BI: 1209091
# Number of columns in df_BI: 18

# %%
df_BI.isnull().sum()
# Out:
# BusinessInteractionId          0
# InstanceId                     0
# StepId                     47547
# ActionCd                       0
# ActionUserId                   0
# StatusCd                       0
# EntityStatusCd                 0
# RelatedPartyId                 0
# Reason                   1191669
# StartTime                      0
# EndTime                     2531
# AppActionCd               667062
# CreateUserId                   0
# CreateUserTime                 0
# UpdateUserId              943459
# UpdateUserTime            939787
# TargetUserId                   0
# TargetGroupId                  0
# dtype: int64

# %% [markdown]
# # What to do with NAs?
# Reason, AppActionCd, UpdateUserTime and UpdateUserId are the columns where most of the cells are empty. Since the userIds and times are not that important and also the Reason column is almost empty, let's drop them. We keep StepID NA rows as they are NA because they cosrrespond to the initial Step (work flow starting step). We can replace the NAs on those cells in the next iteration.

# %%
columns_to_drop = ['Reason', 'AppActionCd', 'UpdateUserTime', 'UpdateUserId']
df_BI_cleaned = df_BI.drop(columns=columns_to_drop)

print("Original columns:", df_BI.columns.tolist())
print("\nColumns after dropping:", df_BI_cleaned.columns.tolist())
df_BI_cleaned.head()
# Out:
# Original columns: ['BusinessInteractionId', 'InstanceId', 'StepId', 'ActionCd', 'ActionUserId', 'StatusCd', 'EntityStatusCd', 'RelatedPartyId', 'Reason', 'StartTime', 'EndTime', 'AppActionCd', 'CreateUserId', 'CreateUserTime', 'UpdateUserId', 'UpdateUserTime', 'TargetUserId', 'TargetGroupId']
#
# Columns after dropping: ['BusinessInteractionId', 'InstanceId', 'StepId', 'ActionCd', 'ActionUserId', 'StatusCd', 'EntityStatusCd', 'RelatedPartyId', 'StartTime', 'EndTime', 'CreateUserId', 'CreateUserTime', 'TargetUserId', 'TargetGroupId']
#    BusinessInteractionId   InstanceId        StepId         ActionCd  \
# 0            10230767264  10003850078  1.000012e+12         SaveStep
# 1            10230767256  10003850078           NaN  WorkflowStarted
# 2            10230767260  10003850078  1.000012e+12        EmailSent
# 3            10232343851  10003850078           NaN   CancelInstance
# 4            10230767273  10003850078  1.000012e+12         SaveStep
#
#    ActionUserId StatusCd EntityStatusCd  RelatedPartyId  \
# 0        573540        W            NEW          347878
# 1        573540        W            NEW          573540
# 2        573540        W            NEW          347878
# 3             4        W            NEW               4
# 4        573540        W            NEW          347878
#
#                  StartTime                  EndTime  CreateUserId  \
# 0  2021-03-19 23:26:18.479  2021-03-19 23:26:18.479        573540
# 1  2021-03-19 23:26:02.260  2021-03-19 23:26:02.260        573540
# 2  2021-03-19 23:26:14.104  2021-03-19 23:26:14.104        573540
# 3  2021-03-24 10:05:48.456  2021-03-24 10:05:48.456             4
# 4  2021-03-19 23:26:21.202  2021-03-19 23:26:21.202        573540
#
#             CreateUserTime  TargetUserId  TargetGroupId
# 0  2021-03-19 23:26:18.588             0              0
# 1  2021-03-19 23:26:11.510             0              0
# 2  2021-03-19 23:26:14.729             0              0
# 3  2021-03-24 10:05:52.972             0              0
# 4  2021-03-19 23:26:21.390             0              0

# %%
df_BI_cleaned.fillna(0, inplace=True)
df_BI_cleaned.isna().sum
# Out:
# <bound method DataFrame.sum of          BusinessInteractionId  InstanceId  StepId  ActionCd  ActionUserId  \
# 0                        False       False   False     False         False
# 1                        False       False   False     False         False
# 2                        False       False   False     False         False
# 3                        False       False   False     False         False
# 4                        False       False   False     False         False
# ...                        ...         ...     ...       ...           ...
# 1209086                  False       False   False     False         False
# 1209087                  False       False   False     False         False
# 1209088                  False       False   False     False         False
# 1209089                  False       False   False     False         False
# 1209090                  False       False   False     False         False
#
#          StatusCd  EntityStatusCd  RelatedPartyId  StartTime  EndTime  \
# 0           False           False           False      False    False
# 1           False           False           False      False    False
# 2           False           False           False      False    False
# 3           False           False           False      False    False
# 4           False           False           False      False    False
# ...           ...             ...             ...        ...      ...
# 1209086     False           False           False      False    False
# 1209087     False           False           False      False    False
# 1209088     False           False           False      False    False
# 1209089     False           False           False      False    False
# 1209090     False           False           False      False    False
#
#          CreateUserId  CreateUserTime  TargetUserId  TargetGroupId
# 0               False           False         False          False
# 1               False           False         False          False
# 2               False           False         False          False
# 3               False           False         False          False
# 4               False           False         False          False
# ...               ...             ...           ...            ...
# 1209086         False           False         False          False
# 1209087         False           False         False          False
# 1209088         False           False         False          False
# 1209089         False           False         False          False
# 1209090         False           False         False          False
#
# [1209091 rows x 14 columns]>

# %% [markdown]
# # Column Types
# Let's check the column types and correct the types of columns if needed.

# %%
df_BI_cleaned.dtypes
# Out:
# BusinessInteractionId      int64
# InstanceId                 int64
# StepId                   float64
# ActionCd                  object
# ActionUserId               int64
# StatusCd                  object
# EntityStatusCd            object
# RelatedPartyId             int64
# StartTime                 object
# EndTime                   object
# CreateUserId               int64
# CreateUserTime            object
# TargetUserId               int64
# TargetGroupId              int64
# dtype: object

# %% [markdown]
# - IDs and Cd's are all categorical and start and end times must be datetime type

# %%
datetime_columns = ['StartTime', 'EndTime', 'CreateUserTime']
for col in datetime_columns:
    df_BI_cleaned[col] = pd.to_datetime(df_BI_cleaned[col], errors='coerce')

categorical_columns = ['ActionCd', 'ActionUserId', 'StatusCd', 'EntityStatusCd', 'RelatedPartyId', 'TargetGroupId']
for col in categorical_columns:
    df_BI_cleaned[col] = df_BI_cleaned[col].astype('category')

print("Data types after conversion:")
df_BI_cleaned.dtypes
# Out:
# Data types after conversion:
# BusinessInteractionId             int64
# InstanceId                        int64
# StepId                          float64
# ActionCd                       category
# ActionUserId                   category
# StatusCd                       category
# EntityStatusCd                 category
# RelatedPartyId                 category
# StartTime                datetime64[ns]
# EndTime                  datetime64[ns]
# CreateUserId                      int64
# CreateUserTime           datetime64[ns]
# TargetUserId                      int64
# TargetGroupId                  category
# dtype: object

# %%
num_distinct_stepid = df_BI_cleaned['StepId'].nunique()
print(f"Number of distinct categories for StepId: {num_distinct_stepid}")
# Out:
# Number of distinct categories for StepId: 229825

# %% [markdown]
# ## 2. Let's clean the Data Set named 'Steps'

# %%
df_S = pd.read_csv("/content/drive/MyDrive/Python Codes/data/raw/Step.csv", sep=';', on_bad_lines='warn')
df_S.head()
# Out:
#           StepId   InstanceId                 StepDefCd StepDefTypeCd  TypeCd  \
# 0  1000011695142  10003850078                 StartStep         Start  Normal
# 1  1000010610388  10003045706                   EndStep           End  Normal
# 2  1000009934726  10003045706        ProblemManagerStep      UserStep  Normal
# 3  1000009932237  10003045706  CancellationApprovalStep      UserStep  Normal
# 4  1000009295771  10003045706                    L2Step      UserStep  Normal
#
#   StatusCd                StartTime  ProcessSlotId  Priority    UserId  \
# 0      CNC  2021-03-19 23:26:02.260            643         1  573540.0
# 1        C  2021-03-11 09:07:51.803            401         1  280417.0
# 2        C  2021-03-04 16:24:00.645            401         1  280417.0
# 3        C  2021-03-04 16:05:00.394            401         1  206061.0
# 4        C  2021-02-26 16:10:40.371            401         1  253676.0
#
#    PoolPartyId  SentUserId  PreviousStepId  ParallelStarterStepId  \
# 0       564906         NaN             NaN                    NaN
# 1       474605         NaN    1.000010e+12                    NaN
# 2       474605         NaN    1.000010e+12                    0.0
# 3       347857         NaN    1.000009e+12                    0.0
# 4       548216         NaN    1.000009e+12                    0.0
#
#   ParallelBranchId  IsProcessed                TakenTime  ResumeTime  \
# 0              NaN         True                      NaN         NaN
# 1              NaN        False                      NaN         NaN
# 2              NaN         True  2021-03-04 16:24:01.239         NaN
# 3              NaN         True  2021-03-04 16:05:00.894         NaN
# 4              NaN         True  2021-03-04 14:37:29.014         NaN
#
#                    EndTime        EntityStatusCd Description  CreateUserId  \
# 0  2021-03-24 10:05:52.409                CANCEL         NaN        573540
# 1  2021-03-11 09:07:52.522                CANCEL         NaN        280417
# 2  2021-03-11 09:07:51.803  CANCELLATIONAPPROVAL         NaN        206061
# 3  2021-03-04 16:24:00.645  CANCELLATIONAPPROVAL         NaN        253676
# 4  2021-03-04 16:05:00.394                  OPEN         NaN        277369
#
#             CreateUserTime  UpdateUserId           UpdateUserTime  \
# 0  2021-03-19 23:26:11.229      573540.0  2021-03-19 23:26:21.374
# 1  2021-03-11 09:07:52.584      280417.0  2021-03-11 09:07:52.616
# 2  2021-03-04 16:24:01.410      280417.0  2021-03-11 09:07:52.366
# 3  2021-03-04 16:05:01.019      206061.0  2021-03-04 16:24:00.692
# 4  2021-02-26 16:10:40.809      253676.0  2021-03-04 16:05:00.487
#
#    OrganizationUnitId
# 0            564906.0
# 1            564906.0
# 2            564906.0
# 3            471624.0
# 4            548216.0

# %%
df_S.shape
# Out:
# (229823, 26)

# %%
df_S.isnull().sum()
# Out:
# StepId                        0
# InstanceId                    0
# StepDefCd                     0
# StepDefTypeCd                 0
# TypeCd                        0
# StatusCd                      0
# StartTime                     0
# ProcessSlotId                 0
# Priority                      0
# UserId                      584
# PoolPartyId                   0
# SentUserId               229823
# PreviousStepId            35050
# ParallelStarterStepId     65302
# ParallelBranchId         222857
# IsProcessed                   0
# TakenTime                 70096
# ResumeTime               229823
# EndTime                    1570
# EntityStatusCd                0
# Description              220513
# CreateUserId                  0
# CreateUserTime                0
# UpdateUserId                443
# UpdateUserTime              443
# OrganizationUnitId         2586
# dtype: int64

# %% [markdown]
# # What to do with NAs?
# Let's first drop the columns where we have lots of NAs and also some columns which we will not use.

# %%
columns_to_drop = ['SentUserId', 'ParallelBranchId', 'ResumeTime', 'Description', 'ParallelStarterStepId', 'TakenTime', 'UpdateUserId', 'UpdateUserTime']
df_S_cleaned = df_S.drop(columns=columns_to_drop)

print("Original columns:", df_S.columns.tolist())
print("\nColumns after dropping:", df_S_cleaned.columns.tolist())
df_S_cleaned.head()
# Out:
# Original columns: ['StepId', 'InstanceId', 'StepDefCd', 'StepDefTypeCd', 'TypeCd', 'StatusCd', 'StartTime', 'ProcessSlotId', 'Priority', 'UserId', 'PoolPartyId', 'SentUserId', 'PreviousStepId', 'ParallelStarterStepId', 'ParallelBranchId', 'IsProcessed', 'TakenTime', 'ResumeTime', 'EndTime', 'EntityStatusCd', 'Description', 'CreateUserId', 'CreateUserTime', 'UpdateUserId', 'UpdateUserTime', 'OrganizationUnitId']
#
# Columns after dropping: ['StepId', 'InstanceId', 'StepDefCd', 'StepDefTypeCd', 'TypeCd', 'StatusCd', 'StartTime', 'ProcessSlotId', 'Priority', 'UserId', 'PoolPartyId', 'PreviousStepId', 'IsProcessed', 'EndTime', 'EntityStatusCd', 'CreateUserId', 'CreateUserTime', 'OrganizationUnitId']
#           StepId   InstanceId                 StepDefCd StepDefTypeCd  TypeCd  \
# 0  1000011695142  10003850078                 StartStep         Start  Normal
# 1  1000010610388  10003045706                   EndStep           End  Normal
# 2  1000009934726  10003045706        ProblemManagerStep      UserStep  Normal
# 3  1000009932237  10003045706  CancellationApprovalStep      UserStep  Normal
# 4  1000009295771  10003045706                    L2Step      UserStep  Normal
#
#   StatusCd                StartTime  ProcessSlotId  Priority    UserId  \
# 0      CNC  2021-03-19 23:26:02.260            643         1  573540.0
# 1        C  2021-03-11 09:07:51.803            401         1  280417.0
# 2        C  2021-03-04 16:24:00.645            401         1  280417.0
# 3        C  2021-03-04 16:05:00.394            401         1  206061.0
# 4        C  2021-02-26 16:10:40.371            401         1  253676.0
#
#    PoolPartyId  PreviousStepId  IsProcessed                  EndTime  \
# 0       564906             NaN         True  2021-03-24 10:05:52.409
# 1       474605    1.000010e+12        False  2021-03-11 09:07:52.522
# 2       474605    1.000010e+12         True  2021-03-11 09:07:51.803
# 3       347857    1.000009e+12         True  2021-03-04 16:24:00.645
# 4       548216    1.000009e+12         True  2021-03-04 16:05:00.394
#
#          EntityStatusCd  CreateUserId           CreateUserTime  \
# 0                CANCEL        573540  2021-03-19 23:26:11.229
# 1                CANCEL        280417  2021-03-11 09:07:52.584
# 2  CANCELLATIONAPPROVAL        206061  2021-03-04 16:24:01.410
# 3  CANCELLATIONAPPROVAL        253676  2021-03-04 16:05:01.019
# 4                  OPEN        277369  2021-02-26 16:10:40.809
#
#    OrganizationUnitId
# 0            564906.0
# 1            564906.0
# 2            564906.0
# 3            471624.0
# 4            548216.0

# %%
df_S_cleaned.isna().sum()
# Out:
# StepId                    0
# InstanceId                0
# StepDefCd                 0
# StepDefTypeCd             0
# TypeCd                    0
# StatusCd                  0
# StartTime                 0
# ProcessSlotId             0
# Priority                  0
# UserId                  584
# PoolPartyId               0
# PreviousStepId        35050
# IsProcessed               0
# EndTime                1570
# EntityStatusCd            0
# CreateUserId              0
# CreateUserTime            0
# OrganizationUnitId     2586
# dtype: int64

# %% [markdown]
# - PreviousStepId is empty for those that have StartStep as the previous step. So we'll replace them with 0 as we did for the previous data set.
# - EndTime is Na for those that are currently being processed.
# - UserId and OrganizationUnitId, we'll consider them later

# %%
df_S_cleaned['PreviousStepId'].fillna(0, inplace=True)
df_S_cleaned.isna().sum()
# Out:
# /tmp/ipython-input-2389435826.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_S_cleaned['PreviousStepId'].fillna(0, inplace=True)
# StepId                   0
# InstanceId               0
# StepDefCd                0
# StepDefTypeCd            0
# TypeCd                   0
# StatusCd                 0
# StartTime                0
# ProcessSlotId            0
# Priority                 0
# UserId                 584
# PoolPartyId              0
# PreviousStepId           0
# IsProcessed              0
# EndTime               1570
# EntityStatusCd           0
# CreateUserId             0
# CreateUserTime           0
# OrganizationUnitId    2586
# dtype: int64

# %% [markdown]
# # Column Types
# Let's check the column types and correct the types of columns if needed.

# %%
df_S_cleaned.dtypes
# Out:
# StepId                  int64
# InstanceId              int64
# StepDefCd              object
# StepDefTypeCd          object
# TypeCd                 object
# StatusCd               object
# StartTime              object
# ProcessSlotId           int64
# Priority                int64
# UserId                float64
# PoolPartyId             int64
# PreviousStepId        float64
# IsProcessed              bool
# EndTime                object
# EntityStatusCd         object
# CreateUserId            int64
# CreateUserTime         object
# OrganizationUnitId    float64
# dtype: object

# %%
datetime_columns = ['StartTime', 'EndTime', 'CreateUserTime']
for col in datetime_columns:
    df_S_cleaned[col] = pd.to_datetime(df_S_cleaned[col], errors='coerce')

categorical_columns = ['StepDefCd', 'StepDefTypeCd', 'StatusCd', 'TypeCd', 'Priority', 'EntityStatusCd']
for col in categorical_columns:
    df_S_cleaned[col] = df_S_cleaned[col].astype('category')

print("Data types after conversion:")
df_S_cleaned.dtypes
# Out:
# Data types after conversion:
# StepId                         int64
# InstanceId                     int64
# StepDefCd                   category
# StepDefTypeCd               category
# TypeCd                      category
# StatusCd                    category
# StartTime             datetime64[ns]
# ProcessSlotId                  int64
# Priority                    category
# UserId                       float64
# PoolPartyId                    int64
# PreviousStepId               float64
# IsProcessed                     bool
# EndTime               datetime64[ns]
# EntityStatusCd              category
# CreateUserId                   int64
# CreateUserTime        datetime64[ns]
# OrganizationUnitId           float64
# dtype: object

# %% [markdown]
# # 3. Let's clean the data set named Instances

# %%
df_I = pd.read_csv("/content/drive/MyDrive/Python Codes/data/raw/Instance.csv", sep=';', on_bad_lines='warn')
df_I.head()
# Out:
#     InstanceId ApplicationCd  WfDefinitionId WfDefinitionCd StatusCd  \
# 0  10003850078    IctProblem            4095    ICT_Problem      CNC
# 1  10003045706    IctProblem            4095    ICT_Problem      CMP
# 2  10002677992    IctProblem            4087    ICT_Problem      CMP
# 3  10005932762    IctProblem            4110    ICT_Problem      CMP
# 4  10005828208    IctProblem            4110    ICT_Problem      CNC
#
#    InstanceSourceId InstanceSourceCd  Priority  ProcessSlotId  \
# 0             10004   DynamicService         1            643
# 1             10006   DynamicService         1            401
# 2             10006   DynamicService         1             86
# 3             10001   DynamicService         1            371
# 4             10001   DynamicService         1            593
#
#                  StartTime  UserId  MasterId                  EndTime  \
# 0  2021-03-19 23:26:02.260  573540         0  2021-03-24 10:05:52.409
# 1  2021-02-25 16:02:58.628  206061         0  2021-03-11 09:08:16.600
# 2  2021-02-15 21:11:11.857  431803         0  2021-02-25 18:39:42.533
# 3  2021-05-17 21:58:06.871  415599         0  2021-05-18 01:13:38.387
# 4  2021-05-14 00:20:52.924  415579         0  2021-05-17 04:00:34.401
#
#    SlaTime EntityStatusCd           Description  RelatedInstanceId  \
# 0      NaN         CANCEL  ICT Problem Yönetimi        10003850078
# 1      NaN         CANCEL  ICT Problem Yönetimi        10003045706
# 2      NaN         CANCEL  ICT Problem Yönetimi        10002677992
# 3      NaN         CANCEL  ICT Problem Yönetimi        10005932762
# 4      NaN         CANCEL  ICT Problem Yönetimi        10005828208
#
#    RelatedStepId                 RelationType  CreateUserId  \
# 0              0  InstanceRelationType.Master        573540
# 1              0  InstanceRelationType.Master        206061
# 2              0  InstanceRelationType.Master        431803
# 3              0  InstanceRelationType.Master        415599
# 4              0  InstanceRelationType.Master        415579
#
#             CreateUserTime  UpdateUserId           UpdateUserTime  \
# 0  2021-03-19 23:26:10.807             4  2021-03-24 10:05:52.409
# 1  2021-02-25 16:02:59.144        280417  2021-03-11 09:08:17.694
# 2  2021-02-15 21:11:12.385        431803  2021-02-15 21:11:21.808
# 3  2021-05-17 21:58:07.199        316614  2021-05-18 01:13:40.309
# 4  2021-05-14 00:20:53.128             4  2021-05-17 04:00:34.401
#
#         groupname                         division  \
# 0  EE-RHB-HRH-RHC  RBINCHB HCBIRECHER & BHNBIEREHB
# 1  EE-RHB-HRH-RHC  RBINCHB HCBIRECHER & BHNBIEREHB
# 2  EE-RHB-HRH-RHC  RBINCHB HCBIRECHER & BHNBIEREHB
# 3  EE-RHB-RHH-CHE  RBINCHB HCBIRECHER & BHNBIEREHB
# 4  EE-RHB-RHH-CHE  RBINCHB HCBIRECHER & BHNBIEREHB
#
#                                    team1                         unit  \
# 0  RBINCHB HCBIRECHER CIHHBRR RRERBBRBEE  HJREHRBI RBINCHB HCBIRECHER
# 1  RBINCHB HCBIRECHER CIHHBRR RRERBBRBEE  HJREHRBI RBINCHB HCBIRECHER
# 2  RBINCHB HCBIRECHER CIHHBRR RRERBBRBEE  HJREHRBI RBINCHB HCBIRECHER
# 3                         CHE HCBIRECHER    RBINCHB HCBIRECHER HBEEBI
# 4                         CHE HCBIRECHER    RBINCHB HCBIRECHER HBEEBI
#
#    startgroupname    LastStepId
# 0  EE-RHB-HRH-RHC  1.000012e+12
# 1  EE-RHB-HRH-RHC  1.000011e+12
# 2  EE-RHB-HRH-RHC  1.000008e+12
# 3  EE-RHB-RHH-CHE  1.000018e+12
# 4  EE-RHB-RHH-CHE  1.000018e+12

# %%
print(f"Number of rows in df_I: {df_I.shape[0]}")
print(f"Number of columns in df_I: {df_I.shape[1]}")
# Out:
# Number of rows in df_I: 35051
# Number of columns in df_I: 29

# %%
df_I.isnull().sum()
# Out:
# InstanceId               0
# ApplicationCd            0
# WfDefinitionId           0
# WfDefinitionCd           0
# StatusCd                 0
# InstanceSourceId         0
# InstanceSourceCd      7698
# Priority                 0
# ProcessSlotId            0
# StartTime                0
# UserId                   0
# MasterId                 0
# EndTime               1559
# SlaTime              35051
# EntityStatusCd           0
# Description              0
# RelatedInstanceId        0
# RelatedStepId            0
# RelationType             0
# CreateUserId             0
# CreateUserTime           0
# UpdateUserId             0
# UpdateUserTime           0
# groupname              734
# division               293
# team1                  360
# unit                   360
# startgroupname         734
# LastStepId               1
# dtype: int64

# %% [markdown]
# # What to do with NAs?
# - Let's first drop the columns where we have lots of NAs. In this case, we'll drop SlaTime. We keep InstanceSourceCd for now.
# - Groupname, team1 and unit are going to be important for us. Since the number of NAs are relatively small, we'll also drop the rows where we have NAs for these columns.

# %%
columns_to_drop = ['SlaTime', 'UserId', 'RelatedInstanceId', 'RelationType', 'CreateUserId', 'UpdateUserId']
df_I_cleaned = df_I.drop(columns=columns_to_drop)

columns_NA = ['groupname', 'team1', 'unit', 'LastStepId']
df_I_cleaned.dropna(subset=columns_NA, inplace=True)

print(f"Shape of df_I_cleaned after dropping 'SlaTime' and NA 'groupname, team1, unit' rows: {df_I_cleaned.shape}")
print("\nNull values after operations:")
df_I_cleaned.isnull().sum()
# Out:
# Shape of df_I_cleaned after dropping 'SlaTime' and NA 'groupname, team1, unit' rows: (34249, 23)
#
# Null values after operations:
# InstanceId             0
# ApplicationCd          0
# WfDefinitionId         0
# WfDefinitionCd         0
# StatusCd               0
# InstanceSourceId       0
# InstanceSourceCd    7280
# Priority               0
# ProcessSlotId          0
# StartTime              0
# MasterId               0
# EndTime             1446
# EntityStatusCd         0
# Description            0
# RelatedStepId          0
# CreateUserTime         0
# UpdateUserTime         0
# groupname              0
# division               0
# team1                  0
# unit                   0
# startgroupname         0
# LastStepId             0
# dtype: int64

# %% [markdown]
# # Column Types
# Let's check the column types and correct the types of columns if needed.

# %%
df_I_cleaned.dtypes
# Out:
# InstanceId            int64
# ApplicationCd        object
# WfDefinitionId        int64
# WfDefinitionCd       object
# StatusCd             object
# InstanceSourceId      int64
# InstanceSourceCd     object
# Priority              int64
# ProcessSlotId         int64
# StartTime            object
# MasterId              int64
# EndTime              object
# EntityStatusCd       object
# Description          object
# RelatedStepId         int64
# CreateUserTime       object
# UpdateUserTime       object
# groupname            object
# division             object
# team1                object
# unit                 object
# startgroupname       object
# LastStepId          float64
# dtype: object

# %%
datetime_columns = ['StartTime', 'EndTime', 'CreateUserTime', 'UpdateUserTime']
for col in datetime_columns:
    df_I_cleaned[col] = pd.to_datetime(df_I_cleaned[col], errors='coerce')

categorical_columns = ['ApplicationCd', 'WfDefinitionCd', 'StatusCd', 'InstanceSourceCd', 'Priority', 'EntityStatusCd', 'Description', 'groupname', 'division', 'team1', 'unit', 'startgroupname']
for col in categorical_columns:
    df_I_cleaned[col] = df_I_cleaned[col].astype('category')

print("Data types after conversion:")
df_I_cleaned.dtypes
# Out:
# Data types after conversion:
# InstanceId                   int64
# ApplicationCd             category
# WfDefinitionId               int64
# WfDefinitionCd            category
# StatusCd                  category
# InstanceSourceId             int64
# InstanceSourceCd          category
# Priority                  category
# ProcessSlotId                int64
# StartTime           datetime64[ns]
# MasterId                     int64
# EndTime             datetime64[ns]
# EntityStatusCd            category
# Description               category
# RelatedStepId                int64
# CreateUserTime      datetime64[ns]
# UpdateUserTime      datetime64[ns]
# groupname                 category
# division                  category
# team1                     category
# unit                      category
# startgroupname            category
# LastStepId                 float64
# dtype: object

# %% [markdown]
# ### Export to CSV

# %%
# Export to CSV
# index=False prevents writing the DataFrame index as a column in the CSV
df_BI_cleaned.to_csv('df_BI_cleaned.csv', index=False)
print("df_BI_cleaned exported to 'df_BI_cleaned.csv'")
df_S_cleaned.to_csv('df_S_cleaned.csv', index=False)
print("df_S_cleaned exported to 'df_S_cleaned.csv'")
df_I_cleaned.to_csv('df_I_cleaned.csv', index=False)
print("df_I_cleaned exported to 'df_I_cleaned.csv'")
# Out:
# df_BI_cleaned exported to 'df_BI_cleaned.csv'
# df_S_cleaned exported to 'df_S_cleaned.csv'
# df_I_cleaned exported to 'df_I_cleaned.csv'

# %% [markdown]
# ### Export to Excel

# %%
# Export to Excel
# sheet_name specifies the name of the sheet in the Excel file
df_BI_cleaned.to_excel('df_BI_cleaned.xlsx', sheet_name='Sheet1', index=False)
print("df_BI_cleaned exported to 'df_BI_cleaned.xlsx'")

# %% [markdown]
# ### Export to Parquet

# %%
# Export to Parquet
# Parquet is a columnar storage format, good for performance on large datasets
df_BI_cleaned.to_parquet('df_BI_cleaned.parquet', index=False)
print("df_BI_cleaned exported to 'df_BI_cleaned.parquet'")
